# %% [markdown]
# # collection.Default

# %%
from collections import defaultdict

# %%
classes = defaultdict(lambda: "Outside")

classes['Math'] = "B23"
classes['Physics'] = "D24"

# %%
classes['Chemistry']
# Out:
# 'Outside'
